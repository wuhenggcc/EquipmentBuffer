# %%
from PPMS.PPMS_example import PPMSExample

test = PPMSExample()
test.get_all()
# Out:
# {'field': 0.397488782418038, 'temperature': 4.072075177629459, 'timestamp': 1763402122.6613724}
# {'field': 0.397488782418038,
#  'temperature': 4.072075177629459,
#  'timestamp': 1763402122.6613724}

# %%
test.set_field(5000,100)
# Out:
# Command response: {'command': 'set_field', 'status': 'queued'}
# {'command': 'set_field', 'status': 'queued'}

# %%
from general.equipment_driver import FakeDriver

driver = FakeDriver(11)
driver.set_field(3,0.5,'linear')
