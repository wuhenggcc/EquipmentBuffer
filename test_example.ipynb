# %%
from PPMS.PPMS_example import PPMSExample

test = PPMSExample()
test.get_all()
# Out:
# {'field': [0.04801106080412865, 'Holding (driven)'], 'temperature': [299.9996643066406, 'Stable'], 'timestamp': 1763993411.1285536}
# {'field': [0.04801106080412865, 'Holding (driven)'],
#  'temperature': [299.9996643066406, 'Stable'],
#  'timestamp': 1763993411.1285536}

# %%
test.set_field(100,10)
# Out:
# Command response: {'command': 'set_field', 'status': 'queued'}
# {'command': 'set_field', 'status': 'queued'}
