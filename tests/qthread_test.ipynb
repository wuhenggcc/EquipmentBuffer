# %%
from PyQt5.QtWidgets import QApplication
import sys
from qthread_test import WorkController

app = QApplication(sys.argv)

controller = WorkController()
sys.exit(app.exec_())
# Out:
# Worker started
# Doing work...
# working... count = 1
# Doing work...
# working... count = 2
# Doing work...
# working... count = 3
# Doing work...
# working... count = 4
# Doing work...
# working... count = 5
# Doing work...
# working... count = 6
# Doing work...
# working... count = 7
# Doing work...
# working... count = 8
# Doing work...
# working... count = 9
# Doing work...
# working... count = 10
# Doing work...
# working... count = 11
# Doing work...
# working... count = 12
# Doing work...
# working... count = 13
# Doing work...
# working... count = 14
# Doing work...
# working... count = 15
# Doing work...
# working... count = 16
# Doing work...
# working... count = 17
# Doing work...
# working... count = 18
# Doing work...
# working... count = 19
# Doing work...
# working... count = 20
# Doing work...
# working... count = 21
# Doing work...
# working... count = 22
# Doing work...
# working... count = 23
# Doing work...
# working... count = 24
